# %%
# %pylab inline
import pandas as pd
import seaborn as sns
import numpy as np
import scipy 
import matplotlib.pyplot as plt
import matplotlib.style as style

import sys
from sklearn.model_selection import train_test_split
import pydot
#imports the own created package
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import export_graphviz

import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#imports pickle file created and saved in 'Feature_extraction.ipynb'
df_final = pd.read_pickle('df_both_seasons_with_features')
df_final.head()
# Out:
#      Day  Month  Year        HomeTeam     AwayTeam  FTHG  FTAG  HST  AST  FTR  \
# 0      9     12  2020          Fulham      Arsenal     0     3    2    6    0
# 2      9     12  2020       Liverpool        Leeds     4     3    6    3    2
# 1      9     12  2020  Crystal Palace  Southampton     1     0    3    5    2
# 3      9     12  2020        West Ham    Newcastle     0     2    3    2    0
# 347    7     12  2020       Tottenham      Arsenal     2     1    9    4    2
#
#      HTGDIFF  ATGDIFF  AVGHTGDIFF  AVGATGDIFF  AVGHP    AVGAP  Form_Diff_P  \
# 0         -3        3    0.100000   -0.400000    1.0  1.20000     -0.20000
# 2          1       -1    2.000000   -0.159517    1.9  1.06858      0.83142
# 1          1       -1    0.200000   -0.200000    0.9  0.80000      0.10000
# 3         -2        2    0.000000   -0.300000    1.0  0.90000      0.10000
# 347        1       -1    0.317771    0.100000    1.3  1.30000      0.00000
#
#      Form_Diff_G
# 0       0.500000
# 2       2.159517
# 1       0.400000
# 3       0.300000
# 347     0.217771

# %%
df_result=df_final.copy()
## On définie la variable qui nous intéresse ( Home Team Result) et on supprime les variables du résultats ( FTHG FTAG HTGDIFF HTR ATGDIFF)
target=df_result["FTR"]

df_result= df_result.drop([
    'Year','FTHG','FTAG','HST','AST','HTGDIFF', 'ATGDIFF','FTR','HomeTeam','AwayTeam'],axis=1)

# %%
# splitting arrays into random train and test subsets
X_train, X_test, y_train, y_test = train_test_split(
    df_result, target, test_size = 0.25,random_state = 28
)

# %%
print('X_train Shape:', X_train.shape)
print('y_train Shape:', y_train.shape)
print('X_test Shape:', X_test.shape)
print('y_test Shape:', y_test.shape)
# Out:
# X_train Shape: (434, 8)
# y_train Shape: (434,)
# X_test Shape: (145, 8)
# y_test Shape: (145,)

# %%
from sklearn.metrics import accuracy_score
#from sklearn.metrics import plot_confusion_matrix
import matplotlib.pyplot as plt  # doctest: +SKIP
def performance_accuracy(y_test,X_test, clf):
    errors=0
    i=0
    y_pred =clf.predict(X_test)
    return accuracy_score(y_test, y_pred)
    
    #plot_confusion_matrix(clf, X_test, y_test)
    #plt.show()

# %%
## First attempt of prediction
clf = RandomForestClassifier(n_estimators=2000,max_features=None,class_weight='balanced',min_samples_split=30,n_jobs=-1,random_state=42)
clf.fit(X_train,y_train)

accuracy=performance_accuracy(y_test,X_test,clf)
print('Accuracy of the model is : ',accuracy)
# Out:
# Accuracy of the model is :  0.4482758620689655

# %%
features=np.array(df_result)
predictions_HTR = clf.predict(features)

df_final["prediction"]=predictions_HTR
df_show=df_final.copy()
df_show= df_show.drop([
   'HST','AST', 'HTGDIFF', 'ATGDIFF','AVGHTGDIFF','AVGHP'],axis=1) 
df_show.head(20)
# Out:
#      Day  Month  Year        HomeTeam          AwayTeam  FTHG  FTAG  FTR  \
# 0      9     12  2020          Fulham           Arsenal     0     3    0
# 2      9     12  2020       Liverpool             Leeds     4     3    2
# 1      9     12  2020  Crystal Palace       Southampton     1     0    2
# 3      9     12  2020        West Ham         Newcastle     0     2    0
# 347    7     12  2020       Tottenham           Arsenal     2     1    2
# 345    7     12  2020          Wolves           Everton     3     0    2
# 346    7     12  2020     Aston Villa    Crystal Palace     2     0    2
# 348    7     12  2020     Bournemouth         Leicester     4     1    2
# 382    2     12  2020         Reading         West Brom     1     2    0
# 381    2     12  2020        Millwall            Fulham     1     1    1
# 217    1     12  2020     Bournemouth           Watford     0     3    0
# 218    1     12  2020     Aston Villa          Man City     1     6    0
# 97    30     11  2020        West Ham       Aston Villa     2     1    2
# 96    30     11  2020       Leicester            Fulham     1     2    0
# 95    29     11  2020         Arsenal            Wolves     1     2    0
# 93    29     11  2020     Southampton        Man United     2     3    0
# 94    29     11  2020         Chelsea         Tottenham     0     0    1
# 91    28     11  2020         Everton             Leeds     0     1    0
# 90    28     11  2020        Man City           Burnley     5     0    2
# 92    28     11  2020       West Brom  Sheffield United     1     0    2
#
#      AVGATGDIFF    AVGAP  prediction
# 0     -0.400000  1.20000           0
# 2     -0.159517  1.06858           2
# 1     -0.200000  0.80000           1
# 3     -0.300000  0.90000           0
# 347    0.100000  1.30000           2
# 345   -0.159517  1.70000           2
# 346   -0.159517  1.60000           2
# 348   -0.159517  0.80000           1
# 382    0.700000  1.10000           0
# 381   -0.159517  1.10000           0
# 217   -0.159517  1.60000           2
# 218   -0.159517  0.60000           0
# 97    -0.500000  1.50000           2
# 96    -0.100000  1.00000           0
# 95     0.200000  0.70000           0
# 93     1.300000  0.30000           0
# 94     0.100000  1.00000           2
# 91    -0.159517  1.06858           0
# 90    -0.159517  1.06858           2
# 92    -1.000000  1.06858           2

# %%
importances=clf.feature_importances_
columns=df_result.columns
d= {"columns":columns,"importances":importances}
df=pd.DataFrame(d)
df
# Out:
#        columns  importances
# 0          Day     0.096338
# 1        Month     0.056677
# 2   AVGHTGDIFF     0.073982
# 3   AVGATGDIFF     0.072545
# 4        AVGHP     0.177606
# 5        AVGAP     0.147905
# 6  Form_Diff_P     0.097472
# 7  Form_Diff_G     0.277474

# %%
from sklearn.model_selection import RandomizedSearchCV
def random_search(X_train,y_train, n_estimators=1000, n_iter=200, cv=3):
    # creating the parameter grid with variables
    param_grid = {
        'n_estimators': np.linspace(10, 2*n_estimators).astype(int),
        'max_depth': [None] + list(np.linspace(3, 45).astype(int)),
        'max_features': ['auto', 'sqrt', None] + list(np.arange(1, 1, 4)),
        'max_leaf_nodes': [None] + list(np.linspace(10, 20, 500).astype(int)),
        'min_samples_split': [ 10,15,20,30,40,50],
        'bootstrap': [True, False]
    }

    # RandomForestClassifier selected as estimator
    clf = RandomForestClassifier(class_weight='balanced',random_state = 42)

    # create randomized search 
    # as described here: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html
    rscv = RandomizedSearchCV(clf, param_grid, n_jobs = -1, cv = cv, 
                            n_iter = n_iter, verbose = 1, random_state=27)

    # refit 
    rscv.fit(X_train,y_train)
    return rscv

# %%
rs=random_search(X_train,y_train,cv=3)
# Out:
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 600 out of 600 | elapsed:  6.5min finished

# %%
best_params = rs.best_params_
print(best_params)
# Out:
# {'n_estimators': 213, 'min_samples_split': 10, 'max_leaf_nodes': 15, 'max_features': 'auto', 'max_depth': 18, 'bootstrap': True}

# %%
clf_optimized = RandomForestClassifier(n_estimators=213,min_samples_split=10,max_features='auto',max_leaf_nodes=15,max_depth=18,n_jobs=-1,random_state=42)
clf_optimized.fit(X_train,y_train)

accuracy=performance_accuracy(y_test,X_test,clf_optimized)
print('Accuracy of the optimized model is : ',accuracy)
# Out:
# Accuracy of the optimized model is :  0.503448275862069

# %%
importances=clf_optimized.feature_importances_
columns=df_result.columns
d= {"columns":columns,"importances":importances}
df=pd.DataFrame(d)
df
# Out:
#        columns  importances
# 0          Day     0.063646
# 1        Month     0.045235
# 2   AVGHTGDIFF     0.116937
# 3   AVGATGDIFF     0.103416
# 4        AVGHP     0.171976
# 5        AVGAP     0.162016
# 6  Form_Diff_P     0.102253
# 7  Form_Diff_G     0.234520

# %%
features=np.array(df_result)
predictions_FTR = clf_optimized.predict(features)

df_final["prediction"]=predictions_FTR
df_show=df_final.copy()
df_show= df_show.drop([
   'HST','AST', 'HTGDIFF', 'ATGDIFF','AVGHTGDIFF','AVGHP','AVGAP','AVGATGDIFF','Form_Diff_P','Form_Diff_G'],axis=1) 
df_show.head(20)
# Out:
#      Day  Month  Year        HomeTeam          AwayTeam  FTHG  FTAG  FTR  \
# 0      9     12  2020          Fulham           Arsenal     0     3    0
# 2      9     12  2020       Liverpool             Leeds     4     3    2
# 1      9     12  2020  Crystal Palace       Southampton     1     0    2
# 3      9     12  2020        West Ham         Newcastle     0     2    0
# 347    7     12  2020       Tottenham           Arsenal     2     1    2
# 345    7     12  2020          Wolves           Everton     3     0    2
# 346    7     12  2020     Aston Villa    Crystal Palace     2     0    2
# 348    7     12  2020     Bournemouth         Leicester     4     1    2
# 382    2     12  2020         Reading         West Brom     1     2    0
# 381    2     12  2020        Millwall            Fulham     1     1    1
# 217    1     12  2020     Bournemouth           Watford     0     3    0
# 218    1     12  2020     Aston Villa          Man City     1     6    0
# 97    30     11  2020        West Ham       Aston Villa     2     1    2
# 96    30     11  2020       Leicester            Fulham     1     2    0
# 95    29     11  2020         Arsenal            Wolves     1     2    0
# 93    29     11  2020     Southampton        Man United     2     3    0
# 94    29     11  2020         Chelsea         Tottenham     0     0    1
# 91    28     11  2020         Everton             Leeds     0     1    0
# 90    28     11  2020        Man City           Burnley     5     0    2
# 92    28     11  2020       West Brom  Sheffield United     1     0    2
#
#      prediction
# 0             1
# 2             2
# 1             2
# 3             0
# 347           2
# 345           2
# 346           2
# 348           0
# 382           0
# 381           2
# 217           2
# 218           0
# 97            2
# 96            0
# 95            0
# 93            0
# 94            2
# 91            0
# 90            2
# 92            1
