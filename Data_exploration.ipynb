# %%
# %pylab inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as style
import sys

import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## Load Premier League and Championship results of last season + current PL season
df_current_season=pd.read_csv('PL_Results_20_21.csv')
df_last_season=pd.read_csv('PL_Results_19_20.csv')
df_D2_last_season=pd.read_csv('Championship_Results_19_20.csv')

# %% [raw]
# Preparation et traitement des données

# %%
df_current_season.columns
# Out:
# Index(['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG',
#        ...
#        'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH',
#        'MaxCAHA', 'AvgCAHH', 'AvgCAHA'],
#       dtype='object', length=106)

# %%
## Récupérer les données des 3 promus en PL : Leeds United, Fulham FC et West Bromwich Albion
df_leeds_home=df_D2_last_season[df_D2_last_season['HomeTeam']=='Leads']
df_leeds_away=df_D2_last_season[df_D2_last_season['AwayTeam']=='Leads']
df_fulham_home=df_D2_last_season[df_D2_last_season['HomeTeam']=='Fulham']
df_fulham_away=df_D2_last_season[df_D2_last_season['AwayTeam']=='Fulham']
df_west_brom_home=df_D2_last_season[df_D2_last_season['HomeTeam']=='West Brom']
df_west_brom_away=df_D2_last_season[df_D2_last_season['AwayTeam']=='West Brom']
df_D2_last_season=pd.concat([df_leeds_home,df_leeds_away,df_fulham_home,df_fulham_away,df_west_brom_home,df_west_brom_away],axis=0)

# %%
## Concaténer les résultats des promus avec les résultats de la saison passée de PL
df_last_season=pd.concat([df_last_season,df_D2_last_season],axis=0)

# %%
teams_s1 = df_current_season.columns.unique()

# %%
teams_s1.shape
# Out:
# (106,)

# %%
teams_last=df_last_season.columns.unique()
teams_last.shape
# Out:
# (106,)

# %%
df_both_seasons = pd.concat([df_current_season, df_last_season], axis=0)

# %%
df_both_seasons['Date'] = pd.to_datetime(df_both_seasons['Date'], errors='coerce')

# %%
df_both_seasons['Day'] = df_both_seasons['Date'].dt.day
df_both_seasons['Month'] = df_both_seasons['Date'].dt.month
df_both_seasons['Year'] = df_both_seasons['Date'].dt.year

# %%
df_both_seasons_essentials = df_both_seasons[['Day','Month','Year','HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'HST', 'AST','FTR']]

# %%
##On remplace les valeurs String par des valeurs numériques ( Victoire =2 ,Nul=1 , Défaite=0) par rapport à l'equipe locale
df_both_seasons_essentials['FTR'].replace({"H":2,"D":1,"A":0},inplace=True)

df_both_seasons_essentials.head(20)
# Out:
#     Day  Month  Year          HomeTeam          AwayTeam  FTHG  FTAG  HST  \
# 0     9     12  2020            Fulham           Arsenal     0     3    2
# 1     9     12  2020    Crystal Palace       Southampton     1     0    3
# 2     9     12  2020         Liverpool             Leeds     4     3    6
# 3     9     12  2020          West Ham         Newcastle     0     2    3
# 4    13      9  2020         West Brom         Leicester     0     3    1
# 5    13      9  2020         Tottenham           Everton     0     1    5
# 6    14      9  2020          Brighton           Chelsea     1     3    3
# 7    14      9  2020  Sheffield United            Wolves     0     2    2
# 8    19      9  2020           Everton         West Brom     5     2    7
# 9    19      9  2020             Leeds            Fulham     4     3    7
# 10   19      9  2020        Man United    Crystal Palace     1     3    4
# Watford            19     19    19        19    19    19   19   19   19
# West Brom          30     30    30        30    30    30   30   30   30
# West Ham           25     25    25        25    25    25   25   25   25
# Wigan               2      2     2         2     2     2    2    2    2
# Wolves             24     24    24        24    24    24   24   24   24

# %%
## On ajoute deux colonnes pour les différences de buts
df_both_seasons_essentials['HTGDIFF'] = df_both_seasons_essentials['FTHG'] - df_both_seasons_essentials['FTAG']
df_both_seasons_essentials['ATGDIFF'] = df_both_seasons_essentials['FTAG'] - df_both_seasons_essentials['FTHG']

# %%
df_both_seasons_essentials.groupby('HomeTeam').head()
# Out:
#      Day  Month  Year          HomeTeam          AwayTeam  FTHG  FTAG  HST  \
# 0      9     12  2020            Fulham           Arsenal     0     3    2
# 1      9     12  2020    Crystal Palace       Southampton     1     0    3
# 2      9     12  2020         Liverpool             Leeds     4     3    6
# 3      9     12  2020          West Ham         Newcastle     0     2    3
# 4     13      9  2020         West Brom         Leicester     0     3    1
# 5     13      9  2020         Tottenham           Everton     0     1    5
# 6     14      9  2020          Brighton           Chelsea     1     3    3
# 7     14      9  2020  Sheffield United            Wolves     0     2    2
# 8     19      9  2020           Everton         West Brom     5     2    7
# 9     19      9  2020             Leeds            Fulham     4     3    7
# 10    19      9  2020        Man United    Crystal Palace     1     3    4
# 11    19      9  2020           Arsenal          West Ham     2     1    3
# 12    20      9  2020       Southampton         Tottenham     2     5    7
# 13    20      9  2020         Newcastle          Brighton     0     3    0
# 14    20      9  2020           Chelsea         Liverpool     0     2    3
# 15    20      9  2020         Leicester           Burnley     4     2    6
# 16    21      9  2020       Aston Villa  Sheffield United     1     0    2
# 17    21      9  2020            Wolves          Man City     1     3    1
# 18    26      9  2020          Brighton        Man United     2     3    5
# 19    26      9  2020    Crystal Palace           Everton     1     2    1
# 20    26      9  2020         West Brom           Chelsea     3     3    3
# 21    26      9  2020           Burnley       Southampton     0     1    2
# 22    27      9  2020  Sheffield United             Leeds     0     1    4
# 23    27      9  2020         Tottenham         Newcastle     1     1   12
# 24    27      9  2020          Man City         Leicester     2     5    5
# 25    27      9  2020          West Ham            Wolves     4     0    7
# 26    28      9  2020            Fulham       Aston Villa     0     3    3
# 27    28      9  2020         Liverpool           Arsenal     3     1    8
# 28    10      3  2020           Chelsea    Crystal Palace     4     0    6
# 29    10      3  2020           Everton          Brighton     4     2    6
# ..   ...    ...   ...               ...               ...   ...   ...  ...
# 315    1     11  2020              Hull            Fulham     0     1    2
# 337   22      1  2020          Charlton            Fulham     0     0    1
# 363    2      8  2020         Blackburn            Fulham     0     1    1
# 381    2     12  2020          Millwall            Fulham     1     1    2
# 396   21      2  2020             Derby            Fulham     1     1    7
# 433    3      7  2020      Bristol City            Fulham     1     1    8
# 472   30      6  2020               QPR            Fulham     1     2    2
# 492    7      7  2020     Nott'm Forest            Fulham     0     1    4
# 551   22      7  2020             Wigan            Fulham     1     1    7
# 9      8      3  2019     Nott'm Forest         West Brom     1     2    4
# 29    17      8  2019             Luton         West Brom     1     2    4
# 48    24      8  2019             Derby         West Brom     1     1    4
# 98    28      9  2019               QPR         West Brom     0     2    0
# 140   19     10  2019     Middlesbrough         West Brom     0     1    7
# 178   11      4  2019             Stoke         West Brom     0     2    3
# 182   11      9  2019              Hull         West Brom     0     1    3
# 226   12      2  2019           Preston         West Brom     0     1    2
# 250   12     11  2019             Wigan         West Brom     1     1    5
# 252   14     12  2019        Birmingham         West Brom     2     3    6
# 275   26     12  2019          Barnsley         West Brom     1     1    8
# 314    1     11  2020          Charlton         West Brom     2     2    2
# 342   28      1  2020           Cardiff         West Brom     2     1    5
# 371    2      9  2020          Millwall         West Brom     0     2    3
# 382    2     12  2020           Reading         West Brom     1     2    1
# 400   22      2  2020      Bristol City         West Brom     0     3    1
# 441    3      7  2020           Swansea         West Brom     0     0    2
# 456   26      6  2020         Brentford         West Brom     1     0    2
# 478    7      1  2020    Sheffield Weds         West Brom     0     3    2
# 509    7     11  2020         Blackburn         West Brom     1     1    4
# 528   17      7  2020      Huddersfield         West Brom     2     1    4
#
#      AST  FTR  HTGDIFF  ATGDIFF
# 0      6    0       -3        3
# 1      5    2        1       -1
# 2      3    2        1       -1
# 3      2    0       -2        2
# 4      7    0       -3        3
# 5      4    0       -1        1
# 6      5    0       -2        2
# 7      4    0       -2        2
# 8      4    2        3       -3
# 9      6    2        1       -1
# 10     5    0       -2        2
# 11     3    2        1       -1
# 12     6    0       -3        3
# 13     6    0       -3        3
# 14     6    0       -2        2
# 15     5    2        2       -2
# 16     1    2        1       -1
# 17     9    0       -2        2
# 18     3    0       -1        1
# 19     5    0       -1        1
# 20    10    1        0        0
# 21     1    0       -1        1
# 22     9    0       -1        1
# 23     1    1        0        0
# 24     7    0       -3        3
# 25     2    2        4       -4
# 26     5    0       -3        3
# 27     3    2        2       -2
# 28     0    2        4       -4
# 29     3    2        2       -2
# ..   ...  ...      ...      ...
# 315    1    0       -1        1
# 337    4    1        0        0
# 363    4    0       -1        1
# 381    2    1        0        0
# 396    5    1        0        0
# 433    5    1        0        0
# 472    5    0       -1        1
# 492    2    0       -1        1
# 551    4    1        0        0
# 9      3    0       -1        1
# 29     3    0       -1        1
# 48     4    1        0        0
# 98     7    0       -2        2
# 140    4    0       -1        1
# 178    3    0       -2        2
# 182    2    0       -1        1
# 226    4    0       -1        1
# 250    2    1        0        0
# 252    3    0       -1        1
# 275    2    1        0        0
# 314    5    1        0        0
# 342    3    2        1       -1
# 371    6    0       -2        2
# 382    7    0       -1        1
# 400    8    0       -3        3
# 441    1    1        0        0
# 456    2    2        1       -1
# 478    4    0       -3        3
# 509    8    1        0        0
# 528    4    2        1       -1
#
# [157 rows x 12 columns]

# %%
##ON sauvegarde nos données après prétraitements
import pickle
df_both_seasons_essentials.to_pickle('df_both_seasons_essentials')
